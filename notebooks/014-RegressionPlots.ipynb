# %%
# %matplotlib inline
from __future__ import print_function, division

import numpy as np; np.random.seed(42)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_palette(sns.color_palette('viridis'))
plt.rcParams['figure.figsize'] = (20, 6)

from sympy.plotting import plot_implicit

import sympy as sy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-f8ca6ea77785> in <module>()
#      10
#      11 from sympy.plotting import plot_implicit
# ---> 12 from sympy.solvers import implicit
#      13 import sympy as sy
#
# ImportError: cannot import name implicit

# %%
sy.var('x y')
l2_pen = x**2 + y**2
l1_pen = np.abs(x) + np.abs(y)
l1_rat = 1.0
l2_rat = 1.0 - l1_rat
p = plot_implicit(l1_rat * l1_pen + l2_rat * l2_pen <= 1)

# %%
fig.show()

# %%
delta = 0.003
lim_low = -4
lim_hi = 4

xrange = np.arange(lim_low, lim_hi, delta)
yrange = np.arange(lim_low, lim_hi, delta)

X, Y = np.meshgrid(xrange,yrange)

# F is one side of the equation, G is the other
F = np.abs(X) + np.abs(Y)
G = 10

plt.contour(X, Y, (F - G), [0])
plt.show()
