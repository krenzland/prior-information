# %%
# %matplotlib inline

import sys, os
sys.path.append(os.path.abspath(os.path.join('..', 'src/')))
from sgpi.util import get_dataset, get_xy, get_r_squared, split, to_data_matrix
from sgpi.plot import *

import pandas as pd
import pysgpp as sg

# %%
df = get_dataset('friedman1')

# %%
lambdas = plot_cox_df(df)

# %%
lambdas
# Out:
# {'x1': 0.73772299748812553,
#  'x10': 0.81728280581171431,
#  'x2': 0.80698183857607453,
#  'x3': 0.73814877672198154,
#  'x4': 0.65907211104558194,
#  'x5': 0.88664969513868797,
#  'x6': 0.78156577216859524,
#  'x7': 0.73707418190834051,
#  'x8': 0.77589583265069417,
#  'x9': 0.80351813801046301,
#  'y': 1}

# %%
get_dataset('friedman1').describe()
# Out:
#                  x1            x2            x3            x4            x5  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.517651      0.511262      0.514356      0.517864      0.515024
# std        0.288912      0.290026      0.287355      0.287232      0.290995
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.271404      0.259307      0.270173      0.270813      0.262057
# 50%        0.527813      0.520834      0.521791      0.519465      0.525661
# 75%        0.770992      0.763105      0.760853      0.768036      0.766294
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  x6            x7            x8            x9           x10  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.514581      0.515063      0.513697      0.513202      0.514638
# std        0.289434      0.288069      0.287709      0.291429      0.289847
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.268650      0.268183      0.265025      0.259764      0.267224
# 50%        0.520454      0.522190      0.520681      0.520913      0.521187
# 75%        0.766297      0.763582      0.765938      0.771270      0.768188
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                   y
# count  10000.000000
# mean      14.408820
# std        4.959348
# min        0.452433
# 25%       10.898531
# 50%       14.396593
# 75%       17.969089
# max       28.377406
